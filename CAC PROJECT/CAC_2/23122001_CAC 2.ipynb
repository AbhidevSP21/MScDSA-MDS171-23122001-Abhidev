# %% [markdown]
# ## Analysis of E-Commerce Platforms

# %% [markdown]
# ### Importing the Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Basic Analysis of the Dataset

# %%
df = pd.read_csv("E-Commerce Python (Responses) (2).csv")

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#                Timestamp                               Email Address  \
# 0    10-12-2023 20:40:55     mohammed.rayan@msds.christuniversity.in
# 1    10-12-2023 20:57:24      jyosna.philip@msds.christuniversity.in
# 2    10-12-2023 20:59:56           chirag.n@msds.christuniversity.in
# 3    10-12-2023 21:02:27    nandhana.rajeev@msds.christuniversity.in
# 4    10-12-2023 21:14:40    trikalagga.saha@msds.christuniversity.in
# ..                   ...                                         ...
# 271  10-25-2023 17:39:37       angel.johnson@law.christuniversity.in
# 272  10-25-2023 17:40:52  annmariya.jimmy@bbabah.christuniversity.in
# 273  10-25-2023 17:42:42     Nupoor.bhute@bbabah.christeniversity.in
# 274  10-25-2023 17:44:57   Chaitanya.gaur@bbabah.christuniversity.in
# 275                  NaN                                         NaN
#
#     What is your age? What is your gender? Citizenship  \
# 0               20-22                 Male      Indian
# ...

# %%
df = df.rename(columns={df.columns[2]:"Age",df.columns[3]:"Gender",df.columns[5]:"Region",df.columns[6]:"Department",df.columns[7]:"Geographic Area",df.columns[8]:"Frequency of Shopping",df.columns[9]:"Monthly Allowance",df.columns[10]:"Residence",df.columns[11]:"Preference of Product(Online)",df.columns[12]:"Indian E-Commerce Platform(Used)",df.columns[13]:"Expenditure for Online Shopping",df.columns[14]:"Factors for Online Shopping",df.columns[15]:"Improvements",df.columns[16]:"Satisfaction Level for Shopping Online"})

# %%
df
# Out:
#                Timestamp                               Email Address    Age  \
# 0    10-12-2023 20:40:55     mohammed.rayan@msds.christuniversity.in  20-22
# 1    10-12-2023 20:57:24      jyosna.philip@msds.christuniversity.in  20-22
# 2    10-12-2023 20:59:56           chirag.n@msds.christuniversity.in  20-22
# 3    10-12-2023 21:02:27    nandhana.rajeev@msds.christuniversity.in  18-20
# 4    10-12-2023 21:14:40    trikalagga.saha@msds.christuniversity.in  20-22
# ..                   ...                                         ...    ...
# 271  10-25-2023 17:39:37       angel.johnson@law.christuniversity.in  20-22
# 272  10-25-2023 17:40:52  annmariya.jimmy@bbabah.christuniversity.in  20-22
# 273  10-25-2023 17:42:42     Nupoor.bhute@bbabah.christeniversity.in  20-22
# 274  10-25-2023 17:44:57   Chaitanya.gaur@bbabah.christuniversity.in  20-22
# 275                  NaN                                         NaN    NaN
#
# ...

# %%
df.head()
# Out:
#              Timestamp                             Email Address    Age  \
# 0  10-12-2023 20:40:55   mohammed.rayan@msds.christuniversity.in  20-22
# 1  10-12-2023 20:57:24    jyosna.philip@msds.christuniversity.in  20-22
# 2  10-12-2023 20:59:56         chirag.n@msds.christuniversity.in  20-22
# 3  10-12-2023 21:02:27  nandhana.rajeev@msds.christuniversity.in  18-20
# 4  10-12-2023 21:14:40  trikalagga.saha@msds.christuniversity.in  20-22
#
#    Gender Citizenship       Region Department Geographic Area  \
# 0    Male      Indian    Karnataka     MSc DS           Urban
# 1  Female      Indian       Kerala     MSc DS           Rural
# 2    Male      Indian    Karnataka     MSc DS           Urban
# 3  Female      Indian       Kerala     MSc DS           Rural
# 4  Female      Indian  West Bengal     MSc DS           Urban
#
#   Frequency of Shopping Monthly Allowance     Residence  \
# 0                Rarely        5000-10000     Portofino
# ...

# %%
df.tail()
# Out:
#                Timestamp                               Email Address    Age  \
# 271  10-25-2023 17:39:37       angel.johnson@law.christuniversity.in  20-22
# 272  10-25-2023 17:40:52  annmariya.jimmy@bbabah.christuniversity.in  20-22
# 273  10-25-2023 17:42:42     Nupoor.bhute@bbabah.christeniversity.in  20-22
# 274  10-25-2023 17:44:57   Chaitanya.gaur@bbabah.christuniversity.in  20-22
# 275                  NaN                                         NaN    NaN
#
#      Gender Citizenship     Region Department Geographic Area  \
# 271  Female      Indian     Kerala     BA LLb           Urban
# 272  Female      Indian     Kerala        BBA           Urban
# 273  Female      Indian    Haryana        BBA             NaN
# 274  Female      Indian  Karnataka        BBA           Rural
# 275     NaN         NaN        NaN        NaN             NaN
#
#     Frequency of Shopping Monthly Allowance  Residence  \
# 271               Monthly        5000-10000  Residence
# ...

# %%
df.isnull().sum()  #Checks for Null Values
# Out:
# Timestamp                                 1
# Email Address                             1
# Age                                       1
# Gender                                    1
# Citizenship                               1
# Region                                    1
# Department                                1
# Geographic Area                           4
# Frequency of Shopping                     1
# Monthly Allowance                         1
# Residence                                 2
# Preference of Product(Online)             1
# Indian E-Commerce Platform(Used)          1
# Expenditure for Online Shopping           1
# Factors for Online Shopping               1
# Improvements                              1
# Satisfaction Level for Shopping Online    1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Timestamp                               275 non-null    object
#  1   Email Address                           275 non-null    object
#  2   Age                                     275 non-null    object
#  3   Gender                                  275 non-null    object
#  4   Citizenship                             275 non-null    object
#  5   Region                                  275 non-null    object
#  6   Department                              275 non-null    object
#  7   Geographic Area                         272 non-null    object
#  8   Frequency of Shopping                   275 non-null    object
#  9   Monthly Allowance                       275 non-null    object
# ...

# %% [markdown]
# ### Pre-Processing

# %%
df.dropna(subset=['Geographic Area', 'Residence'], inplace=True)

# %%
df['Geographic Area'].fillna('Unknown', inplace=True)

# %%
df=df.drop(["Timestamp","Email Address"],axis=1)

# %%
average1 = int(2000//2)
average2 = int((2000+4000)//2)
average3 = int((4000+6000)//2)
average4 = int((6000+8000)//2)
average5 = int((8000)//2)
df["Expenditure for Online Shopping" ]=df["Expenditure for Online Shopping"].replace('0-₹2000', average1)
df["Expenditure for Online Shopping" ]=df["Expenditure for Online Shopping"].replace('₹2000-₹4000', average2)
df["Expenditure for Online Shopping" ]=df["Expenditure for Online Shopping"].replace('₹4000-₹6000', average3)
df["Expenditure for Online Shopping" ]=df["Expenditure for Online Shopping"].replace('₹6000-₹8000', average4)
df["Expenditure for Online Shopping" ]=df["Expenditure for Online Shopping"].replace('More than 8000', average5)

# %%
averagee1 = int(5000//2)
averagee2 = int((5000+10000)//2)
averagee3 = int((4000+6000)//2)
averagee4 = int((6000+8000)//2)
averagee5 = int((20000)//2)
df["Monthly Allowance" ]=df["Monthly Allowance"].replace('0-5000', averagee1)
df["Monthly Allowance" ]=df["Monthly Allowance"].replace('5000-10000', averagee2)
df["Monthly Allowance" ]=df["Monthly Allowance"].replace('10000-15000', averagee3)
df["Monthly Allowance" ]=df["Monthly Allowance"].replace('15000-20000', averagee4)
df["Monthly Allowance" ]=df["Monthly Allowance"].replace('More than 20000', averagee5)

# %%
df["Frequency of Shopping" ]=df["Frequency of Shopping"].replace("Daily",1)
df["Frequency of Shopping" ]=df["Frequency of Shopping"].replace("Weekly",2)
df["Frequency of Shopping" ]=df["Frequency of Shopping"].replace("Monthly",3)
df["Frequency of Shopping" ]=df["Frequency of Shopping"].replace("Rarely",4)
df["Frequency of Shopping" ]=df["Frequency of Shopping"].replace("Never",5)

# %%
df["Gender"] = df["Gender"].replace("Male",0)
df["Gender"] = df["Gender"].replace("Female",1)

# %%
df
# Out:
#        Age  Gender Citizenship       Region Department Geographic Area  \
# 0    20-22       0      Indian    Karnataka     MSc DS           Urban
# 1    20-22       1      Indian       Kerala     MSc DS           Rural
# 2    20-22       0      Indian    Karnataka     MSc DS           Urban
# 3    18-20       1      Indian       Kerala     MSc DS           Rural
# 4    20-22       1      Indian  West Bengal     MSc DS           Urban
# ..     ...     ...         ...          ...        ...             ...
# 269  20-22       1      Indian      Gujarat        BBA           Urban
# 270  20-22       1      Indian    Karnataka     BA LLb           Urban
# 271  20-22       1      Indian       Kerala     BA LLb           Urban
# 272  20-22       1      Indian       Kerala        BBA           Urban
# 274  20-22       1      Indian    Karnataka        BBA           Rural
#
#      Frequency of Shopping  Monthly Allowance     Residence  \
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### The Satisfaction of Shopping Experience with respect to Gender Analysis

# %%
male_data = df[df['Gender'] == 'Male']
female_data = df[df['Gender'] == 'Female']
male_satisfaction = male_data['Satisfaction Level for Shopping Online']
female_satisfaction = female_data['Satisfaction Level for Shopping Online']

plt.figure(figsize=(10, 10))
plt.hist(male_satisfaction, bins=10, alpha=0.6, label='Male')
plt.hist(female_satisfaction, bins=10, alpha=0.6, label='Female')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.title('Satisfaction Level Histogram by Gender')
plt.legend()
plt.show()

# %% [markdown]
# ### Insight
# - Here we are analyzing the the male and female satisfication on an overall basis, Hence here the Female Satisfaction is more when we try to take the average with respect to the higher satisfaction level. So now lets try to explore one what all basis this satisfaction could be analyzed.

# %% [markdown]
# ## Major Findings

# %% [markdown]
# ### Demographics and E-commerce Platform Choice
#
#
# Explore whether age, gender affect the selection of e-commerce platforms. Are there certain platforms that are more popular among specific demographic groups?

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))
sns.countplot(x='Age', hue='Indian E-Commerce Platform(Used)', data=df)
plt.xlabel('Age')
plt.ylabel('Count') #The count here is nothing but the occurances of various age groups from the dataframe. Whereas the hue looks into the Platforms. 
plt.title('Platform Usage by Age Group')
plt.xticks(rotation=45)
plt.legend(title='Platform')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.countplot(x='Improvements', hue='Indian E-Commerce Platform(Used)', data=df)
plt.xlabel('Improvements')
plt.ylabel('Count')
plt.title('Comparison of Improvements by E-Commerce Platform')
plt.xticks(rotation=45)
plt.legend(title='Platform')
plt.show()

# %%
# import matplotlib.pyplot as plt

# # Group the data by age and platform choice and calculate the mean expenditure
# age_platform_mean_expenditure = df.groupby(['Age', 'Indian E-Commerce Platform(Used)'])['Expenditure for Online Shopping'].mean().unstack()

# # Create a bar chart
# age_platform_mean_expenditure.plot(kind='bar', stacked=True, figsize=(10, 6))
# plt.xlabel('Age Group')
# plt.ylabel('Mean Expenditure')
# plt.title('Mean Expenditure on E-commerce Platforms by Age Group')
# plt.legend(title='Platform', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.show()

# %%
# Similar Graph for the above one.
import seaborn

seaborn.set(style='whitegrid')
tip = seaborn.load_dataset('tips')

seaborn.swarmplot(x='Age', y='Indian E-Commerce Platform(Used)', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Indian E-Commerce Platform(Used)'>

# %%
import matplotlib.pyplot as plt



age_gender_counts = df.groupby(['Age', 'Gender'])['Frequency of Shopping'].count().unstack()

ax = age_gender_counts.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Distribution of Frequency of Shopping by Age and Gender')
plt.xticks(rotation=0)  
plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
platform_counts = df['Indian E-Commerce Platform(Used)'].value_counts()
print(platform_counts)
# Out:
# Indian E-Commerce Platform(Used)
# Amazon      127
# Flipkart     74
# Myntra       59
# Others        8
# Snapdeal      3
# Name: count, dtype: int64

# %% [markdown]
# ### Insights :
#
# - Here the hue is count of the Various Online Platforms(Categorical Values) whereas the the y axis takes the occurances within each age group category. The count indicates the bar's height. Though the maximum usage of online platforms is between 20-22 age group and again the majority of this age group prefers Amazon platform.
#
# - Comparison with the Online Shopping platforms with the Improvements: While taking the average we could infer that the Flipkart requires more improvements in comaprison with the other platforms(In terms of mentioned types). Also with comparison the myntra suggests to be better in terms of Improvements as the complaints are minimal
#
# - Online Shopping Website with Mean Expenditure: 16-18 Age Group spends more and they invest more on Myntra Website when analyzed from the Visualization.
#
# - We create a grouped bar chart where each bar represents an age group, and the different colored segments within each bar represent the distribution of gender within that age group. Hence among the age group of 20-22, Male have higher number of frequency shopping online.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pivot_table = df.groupby(['Frequency of Shopping', 'Indian E-Commerce Platform(Used)']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')
plt.xlabel('Indian E-Commerce Platform(Used)')
plt.ylabel('Frequency of Shopping')
plt.title('Correlation between Frequency of Shopping and Platform Choice')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.violinplot(x='Frequency of Shopping', y='Expenditure for Online Shopping', data=df)
plt.xlabel('Frequency of Shopping')
plt.ylabel('Expenditure for Online Shopping')
plt.title('Violin Plot: Expenditure vs. Frequency of Shopping')
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
plt.hexbin(df['Monthly Allowance'], df['Frequency of Shopping'], gridsize=25, cmap='Blues')
plt.xlabel('Monthly Allowance')
plt.ylabel('Frequency of Shopping')
plt.title('Hexbin Plot: Frequency of Shopping vs. Monthly Allowance')
plt.colorbar(label='Count')
plt.show()

# %% [markdown]
# ### Insights
#
# - Frequency of Shopping with the Expenditure: Monthly and Rarely the number of people prefers Amazon more comapared with the other platforms.
#
# -  Expenditure with the Frequency Shopping: The people who shops daily with the an average with the 3800-4000 spends more monthly basis followed with the 3500 monthly with the people shopping weekly basis.
#
# -  The people shopping monthly with an allowance of  7500 shops more monthly basis and their average expenditure could be around 3500 from their allowance. Around 46 % from their allowance they spends on shopping online.

# %% [markdown]
# ### Regional variations in online shopping behavior.

# %%
df['Region'].value_counts().plot(kind='bar', figsize=(10, 5))

plt.title("Number of online shoppers by make")
plt.ylabel('Number of shoppers')
plt.xlabel('Region')


plt.show()

# %% [markdown]
# Insights: The above analysis is with respect to the regions where there is a higher difference with respect to the viewers as most of the participants are from Kerala then the majority is form West bengal, Tamil Nadu, Uttar Pradesh etc.

# %% [markdown]
# ### **Hostel Residence and Satisfaction with Services**:
# Investigate whether the hostel where participants reside has any correlation with their
# satisfaction levels regarding e-commerce services. Are there hostels that consistently receive
# higher or lower satisfaction ratings?

# %%
import matplotlib.pyplot as plt

residence_satisfaction_counts = df.groupby(['Residence', 'Satisfaction Level for Shopping Online'])["Age"].count().unstack()

ax = residence_satisfaction_counts.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Residence')
plt.ylabel('Count')
plt.title('Distribution of Satisfaction Levels for Shopping Online by Residence')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.legend(title='Satisfaction Level', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Insights:
#
# - The Hostel residents prefer less shopping compared with the private. When it comes to monthly and Rarely the count is high for Private residents.

# %% [markdown]
# ### **Shopping Behavior and Factors Influencing Shopping**:
# Determine whether the factors that influence shopping decisions vary based on shopping
# behavior. Are there different considerations for frequent shoppers compared to infrequent ones?

# %%
crosstab = pd.crosstab(df['Frequency of Shopping'], df['Factors for Online Shopping'])

# Display the crosstab
print(crosstab)
# Out:
# Factors for Online Shopping  Brand reputation  Price  Product reviews/ratings  \
# Frequency of Shopping
# 1                                           3      7                        5
# 2                                           4      7                       15
# 3                                          14     34                       34
# 4                                          13     33                       19
# 5                                           0      0                        2
#
# Factors for Online Shopping  Promotions and discounts  \
# Frequency of Shopping
# 1                                                   4
# 2                                                   2
# 3                                                  10
# 4                                                  13
# 5                                                   0
#
# Factors for Online Shopping  Shipping speed and cost  Stress
# Frequency of Shopping
# ...

# %% [markdown]
# ### Insight
#
# - Here the shopping behaviour and factors influencing shopping is the Price with Product reviews /ratings which is the reason that people tend to purchase products Monthly and Rarely

# %% [markdown]
# ### **Department and Shopping Behavior by E-commerce Platform**:
#
# Analyze whether the department a participant belongs to influences their choice of
# e-commerce platform and their shopping behavior. Are there department-specific trends in
# shopping habits and platform preferences?

# %%
import matplotlib.pyplot as plt



department_shopping_counts = df.groupby(['Department', 'Preference of Product(Online)'])['Age'].count().unstack()


ax = department_shopping_counts.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Department')
plt.ylabel('Count')
plt.title('Shopping Behavior by Department')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Shopping Behavior', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.stripplot(x="Geographic Area", y="Indian E-Commerce Platform(Used)",jitter=.3, data=df)

# Customize the plot
plt.title("Analysis of Geographic Area with the E-Commerce Platforms")
plt.xlabel("Geographic Area")
plt.ylabel("Indian E-Commerce Platform(Used)l")
plt.show()

# %% [markdown]
# ### Insights
#
# - Here the people from the Urban is comparitively more and they prefer Amazon compared with the other E-Commerce platforms. Compared with the other platforms the rural area prefers but the range is less with the other counts of users from platforms.
