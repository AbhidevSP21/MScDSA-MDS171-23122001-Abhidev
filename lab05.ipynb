# %% [markdown]
# Mix & Match Calculator
#
# Create Lists for [Item, Quantity, Price] with 10 random values of your choice.
# The item list can be of any category of your choice [Food Items, Grocery Items,...] or anything you choose that can be bought.
#
# Prepare a CSV file with combinations of these values with the help of random index & looping statements and other control structures we discussed in class.
#
# To get a random index or number to access items from the list, you can use the following:
# random is a library in Python that can be used to generate random numbers.
#
# import random # Importing the external library
# r1 = random.randint(0, 10) # Generating the random number from the range and store it in r1 variable
#
# More details of the Random library usage can be found here.
#
# Your CSV file should have a minimum of 100 rows created randomly with the data in the list and the random library.
# Each row in the CSV file will have (item, Quantity, and UnitPrice).
#
# After preparing the CSV with Python code, you need to compute
# The total cost for each row, display the result from the first 5 rows and the last 10 rows
# Calculate the total cost for each unique item in the dataset.
# Item Name | Total Quantity | Total
# Print the minimum & maximum price for each item sold

# %%
import random

# %%
Items=["Rice","Flour","DishWasher","Olive Oil","Coffee","Sugar","Tea","Detergent","Airfreshner","Salt"]
Quantity= [3,5,6,7,8,6,3,5,6,8]
Price = [230,240,100,230,330,204,332,258,264,635]
Total=[]

# %%
def GroceryItems(Items,Quantity,Price):
    file=open("Practise.csv","w+")
    for i in range(100):
        items=random.randint(0,9)
        quantity=random.randint(0,9)
        price = random.randint(0,9)
        total=Quantity[quantity]*Price[price]
       
        file.write(Items[items]+","+"\t"+str(Quantity[quantity])+","+"\t"+str(Price[price])+","+"\t"+"Total"+str(total)+" \n ")


GroceryItems(Items,Quantity,Price)

# %%
file = open("Practise.csv","r+")
for lines in range(90,100):
    lines = file.readline()
    print(lines)
# Out:
# Detergent,	7,	258,	Total1806
#
#  Coffee,	6,	332,	Total1992
#
#  Sugar,	6,	258,	Total1548
#
#  Flour,	8,	330,	Total2640
#
#  DishWasher,	5,	332,	Total1660
#
#  Airfreshner,	7,	332,	Total2324
#
#  Detergent,	8,	264,	Total2112
#
#  Sugar,	5,	330,	Total1650
#
#  Airfreshner,	3,	230,	Total690
#
#  Rice,	8,	204,	Total1632

# %%
# Calculate the total cost for each unique item in the dataset.
# Item Name | Total Quantity | Total
# Initialize a variable to store the total guest count, the total business is found.
totalcount_rice = 0
totalcount_flour = 0
totalcount_DishWasher = 0
totalcount_OliveOil = 0
totalcount_Coffee = 0
totalcount_Sugar = 0
totalcount_Tea = 0
totalcount_Detergent = 0
totalcount_Airfreshner = 0
totalcount_Salt = 0


netsales_rice=1
netsales_flour = 1
netsales_Dishwasher = 1
netsales_OliveOil = 1
netsales_Coffee = 1
netsales_Sugar = 1
netsales_Tea = 1
netsales_Detergent = 1
netsales_Airfreshner = 1
netsales_Salt = 1

Itemdict = {}
rice_price =[]
flour_price = []
DishWasher_price = []
OliveOil_price = []
Coffee_price = []
Sugar_price = []
Tea_price = []
Detergent_price = []
Airfreshner_price = []
Salt_price = []
with open("Practise.csv", "r") as file:
    for line in file:
        if "Rice" in line:
            lines=line.split()
            rice_price.append(lines[2])
            rice_price.sort()
            if "," in line:
                
                salecount_rice = int(line.split(",")[1].strip())
                # print(salecount)
                totalcount_rice += salecount_rice
                # print(totalcount)
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_rice+=salecount_total
        elif "Flour" in line:
            lines = line.split()
            flour_price.append(lines[2])
            new = flour_price.sort()
            if "," in line:
                salecount_flour = int(line.split(",")[1].strip())
                # print(salecount)
                totalcount_flour += salecount_flour
                # print(totalcount)
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_flour+=salecount_total
        elif "DishWasher" in line:
            lines = line.split()
            DishWasher_price.append(lines[2])
            new = DishWasher_price.sort()
            if "," in line:
                salecount_DishWasher = int(line.split(",")[1].strip())
                totalcount_DishWasher = salecount_DishWasher
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Dishwasher +=salecount_total
        elif "Olive Oil"in line:
            lines = line.split()
            OliveOil_price.append(lines[2])
            new = OliveOil_price.sort()
            if "," in line:
                salecount_OliveOil = int(line.split(",")[1].strip())
                totalcount_OliveOil = salecount_total
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_OliveOil +=salecount_total
        elif "Coffee"in line:
            lines = line.split()
            Coffee_price.append(lines[2])
            new = Coffee_price.sort()
            if "," in line:
                salecount_Coffee = int(line.split(",")[1].strip())
                totalcount_Coffee = salecount_OliveOil
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Coffee +=salecount_total
        elif "Sugar"in line:
            lines = line.split()
            Sugar_price.append(lines[2])
            new = Sugar_price.sort()
            if "," in line:
                salecount_Sugar = int(line.split(",")[1].strip())
                totalcount_Sugar = salecount_Sugar
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Sugar +=salecount_total
        elif "Tea"in line:
            lines = line.split()
            Tea_price.append(lines[2])
            new = Tea_price.sort()
            if "," in line:
                salecount_Tea = int(line.split(",")[1].strip())
                totalcount_Tea = salecount_Tea
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Tea +=salecount_total
        elif "Detergent"in line:
            lines = line.split()
            Detergent_price.append(lines[2])
            new = Detergent_price.sort()
            if "," in line:
                salecount_Detergent = int(line.split(",")[1].strip())
                totalcount_Detergent = salecount_Detergent
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Detergent +=salecount_total
        elif "Airfreshner"in line:
            lines = line.split()
            Airfreshner_price.append(lines[2])
            new = Airfreshner_price.sort()
            if "," in line:
                salecount_Airfreshner = int(line.split(",")[1].strip())
                totalcount_Airfreshner = salecount_Airfreshner
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Airfreshner +=salecount_total
        elif "Salt"in line:
            lines = line.split()
            Salt_price.append(lines[2])
            new = Salt_price.sort()
            if "," in line:
                salecount_Salt = int(line.split(",")[1].strip())
                totalcount_Salt = salecount_Salt
            if "Total" in line:
                salecount_total = int(line.split(",")[2].strip())
                netsales_Salt +=salecount_total
        
                    

print("The Maximum value of Rice is : ",max(rice_price))
print("The Minimum value of Rice is: ",min(rice_price))
print("The Maximum value of Flour is:", max(flour_price))
print("The Minimum value of Flour is:", min(flour_price))
print("The Maximum value of DishWasher is:", max(DishWasher_price))
print("The Minimum value of DishWasher is:", min(DishWasher_price))
print("The Maximum value of Olive Oil is:",max(OliveOil_price))
print("The Minimum value of Olive Oil is:",min(OliveOil_price))
print("The Maximum value of Coffee is:",max(Coffee_price))
print("The Minimum value of Coffee is:",min(Coffee_price))
print("The Maximum value of Sugar is:",max(Sugar_price))
print("The Minimum value of Sugar is:",min(Sugar_price))
print("The Maximum value of Tea is:",max(Tea_price))
print("The Minimum value of Tea is:",min(Tea_price))
print("The Maximum value of Detergent is:",max(Detergent_price))
print("The Minimum value of Detergent is:",min(Detergent_price))
print("The Maximum value of Airfreshner is:",max(Airfreshner_price))
print("The Minimum value of Airfreshner is:",min(Airfreshner_price))
print("The Minimum value of Salt is:",max(Salt_price))
print("The Minimum value of Salt is:",min(Salt_price))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 91
#      89 if "," in line:
#      90     salecount_Coffee = int(line.split(",")[1].strip())
# ---> 91     totalcount_Coffee = salecount_OliveOil
#      92 if "Total" in line:
#      93     salecount_total = int(line.split(",")[2].strip())
#
# NameError: name 'salecount_OliveOil' is not defined

# %%
print("The Item Named Rice {} with Netsales of {}".format(totalcount_rice,netsales_rice))
print("The Item Named Flour {} with Netsales of {}".format(totalcount_flour,netsales_flour))
print("The Item Named DishWasher {} with Netsales of {}".format(totalcount_DishWasher,netsales_Dishwasher))
print("The Item Named Olive Oil {} with Netsales of {}".format(totalcount_OliveOil,netsales_OliveOil))
print("The Item Named Coffee {} with Netsales of {}".format(totalcount_Coffee,netsales_Coffee))
print("The Item Named Sugar {} with Netsales of {}".format(totalcount_Sugar,netsales_Sugar))
print("The Item Named Tea {} with Netsales of {}".format(totalcount_Tea,netsales_Tea))
print("The Item Named Detergent {} with Netsales of {}".format(totalcount_Detergent,netsales_Detergent))
print("The Item Named Airfreshner {} with Netsales of {}".format(totalcount_Airfreshner,netsales_Airfreshner))
print("The Item Named Salt {} with Netsales of {}".format(totalcount_Salt,netsales_Salt))
